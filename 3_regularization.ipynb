# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3
# ------------
#
# Previously in `2_fullyconnected.ipynb`, you trained a logistic regression and a neural network model.
#
# The goal of this assignment is to explore regularization techniques.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 1 to [0.0, 1.0, 0.0 ...], 2 to [0.0, 0.0, 1.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Introduce and tune L2 regularization for both logistic and neural network models. Remember that L2 amounts to adding a penalty on the norm of the weights to the loss. In TensorFlow, you can compute the L2 loss for a tensor `t` using `nn.l2_loss(t)`. The right amount of regularization should improve your validation / test accuracy.
#
# ---

# %% [markdown]
# ### Logistic regression

# %%
batch_size = 128

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  beta_regul = tf.placeholder(tf.float32)
  
  # Variables.
  weights = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  logits = tf.matmul(tf_train_dataset, weights) + biases
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) + beta_regul * tf.nn.l2_loss(weights)
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(
    tf.matmul(tf_valid_dataset, weights) + biases)
  test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, beta_regul : 1e-3}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From C:\Users\alex\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 20.716129
# Minibatch accuracy: 10.9%
# Validation accuracy: 15.4%
# Minibatch loss at step 500: 2.506995
# Minibatch accuracy: 78.9%
# Validation accuracy: 76.2%
# Minibatch loss at step 1000: 1.790857
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.5%
# Minibatch loss at step 1500: 1.016896
# Minibatch accuracy: 82.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 2000: 0.830035
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 2500: 0.884606
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.0%
# Minibatch loss at step 3000: 0.737550
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.9%
# Test accuracy: 88.9%

# %% [markdown]
# ### Neural network

# %%
batch_size = 128
num_hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  beta_regul = tf.placeholder(tf.float32)
  
  # Variables.
  weights1 = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_hidden_nodes]))
  biases1 = tf.Variable(tf.zeros([num_hidden_nodes]))
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes, num_labels]))
  biases2 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  lay1_train = tf.nn.relu(tf.matmul(tf_train_dataset, weights1) + biases1)
  logits = tf.matmul(lay1_train, weights2) + biases2
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) + \
      beta_regul * (tf.nn.l2_loss(weights1) + tf.nn.l2_loss(weights2))
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1)
  valid_prediction = tf.nn.softmax(tf.matmul(lay1_valid, weights2) + biases2)
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1)
  test_prediction = tf.nn.softmax(tf.matmul(lay1_test, weights2) + biases2)

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, beta_regul : 1e-3}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From C:\Users\alex\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 610.369507
# Minibatch accuracy: 8.6%
# Validation accuracy: 33.6%
# Minibatch loss at step 500: 196.449829
# Minibatch accuracy: 83.6%
# Validation accuracy: 79.5%
# Minibatch loss at step 1000: 116.009026
# Minibatch accuracy: 77.3%
# Validation accuracy: 81.7%
# Minibatch loss at step 1500: 68.615005
# Minibatch accuracy: 89.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 2000: 41.149803
# Minibatch accuracy: 92.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 2500: 25.218779
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.8%
# Minibatch loss at step 3000: 15.463775
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Test accuracy: 92.9%

# %% [markdown]
# ---
# Problem 2
# ---------
# Let's demonstrate an extreme case of overfitting. Restrict your training data to just a few batches. What happens?
#
# ---

# %%
batch_size = 128
num_hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  beta_regul = tf.placeholder(tf.float32)
  
  # Variables.
  weights1 = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_hidden_nodes]))
  biases1 = tf.Variable(tf.zeros([num_hidden_nodes]))
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes, num_labels]))
  biases2 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  lay1_train = tf.nn.relu(tf.matmul(tf_train_dataset, weights1) + biases1)
  logits = tf.matmul(lay1_train, weights2) + biases2
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1)
  valid_prediction = tf.nn.softmax(tf.matmul(lay1_valid, weights2) + biases2)
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1)
  test_prediction = tf.nn.softmax(tf.matmul(lay1_test, weights2) + biases2)

# %%
num_steps = 101
num_batches = 3

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    #offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    offset = ((step % num_batches) * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, beta_regul : 1e-3}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 2 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From C:\Users\alex\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 336.366333
# Minibatch accuracy: 8.6%
# Validation accuracy: 27.3%
# Minibatch loss at step 2: 1906.920166
# Minibatch accuracy: 29.7%
# Validation accuracy: 41.5%
# Minibatch loss at step 4: 422.044403
# Minibatch accuracy: 53.1%
# Validation accuracy: 51.8%
# Minibatch loss at step 6: 157.345596
# Minibatch accuracy: 69.5%
# Validation accuracy: 66.5%
# Minibatch loss at step 8: 41.900280
# Minibatch accuracy: 90.6%
# Validation accuracy: 73.4%
# Minibatch loss at step 10: 28.153637
# Minibatch accuracy: 89.8%
# Validation accuracy: 72.8%
# Minibatch loss at step 12: 16.271271
# Minibatch accuracy: 93.0%
# Validation accuracy: 72.4%
# Minibatch loss at step 14: 28.709621
# Minibatch accuracy: 93.0%
# Validation accuracy: 72.9%
# Minibatch loss at step 16: 1.719597
# Minibatch accuracy: 96.9%
# Validation accuracy: 73.8%
# Minibatch loss at step 18: 0.744139
# Minibatch accuracy: 97.7%
# Validation accuracy: 74.2%
# Minibatch loss at step 20: 0.000422
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.3%
# Minibatch loss at step 22: 0.031584
# Minibatch accuracy: 99.2%
# Validation accuracy: 74.3%
# Minibatch loss at step 24: 16.380381
# Minibatch accuracy: 96.1%
# Validation accuracy: 71.5%
# Minibatch loss at step 26: 5.804820
# Minibatch accuracy: 98.4%
# Validation accuracy: 74.5%
# Minibatch loss at step 28: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.2%
# Minibatch loss at step 30: 3.919873
# Minibatch accuracy: 98.4%
# Validation accuracy: 74.3%
# Minibatch loss at step 32: 1.074113
# Minibatch accuracy: 98.4%
# Validation accuracy: 75.0%
# Minibatch loss at step 34: 0.000027
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 36: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 38: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 40: 0.000007
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 42: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 44: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 46: 0.000004
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 48: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 50: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 52: 0.000003
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 54: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 56: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 58: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 60: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 62: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 64: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 66: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 68: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 70: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 72: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 74: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 76: 0.000002
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 78: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 80: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 82: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 84: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 86: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 88: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 90: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 92: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 94: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 96: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 98: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 100: 0.000001
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.0%
# Test accuracy: 82.5%

# %% [markdown]
# ---
# Problem 3
# ---------
# Introduce Dropout on the hidden layer of the neural network. Remember: Dropout should only be introduced during training, not evaluation, otherwise your evaluation results would be stochastic as well. TensorFlow provides `nn.dropout()` for that, but you have to make sure it's only inserted during training.
#
# What happens to our extreme overfitting case?
#
# ---

# %%
batch_size = 128
num_hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weights1 = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_hidden_nodes]))
  biases1 = tf.Variable(tf.zeros([num_hidden_nodes]))
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes, num_labels]))
  biases2 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  lay1_train = tf.nn.relu(tf.matmul(tf_train_dataset, weights1) + biases1)
  drop1 = tf.nn.dropout(lay1_train, 0.5)
  logits = tf.matmul(drop1, weights2) + biases2
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1)
  valid_prediction = tf.nn.softmax(tf.matmul(lay1_valid, weights2) + biases2)
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1)
  test_prediction = tf.nn.softmax(tf.matmul(lay1_test, weights2) + biases2)

# %%
num_steps = 101
num_batches = 3

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    #offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    offset = step % num_batches
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 2 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From C:\Users\alex\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 507.996094
# Minibatch accuracy: 9.4%
# Validation accuracy: 24.3%
# Minibatch loss at step 2: 1167.370605
# Minibatch accuracy: 48.4%
# Validation accuracy: 34.2%
# Minibatch loss at step 4: 407.045166
# Minibatch accuracy: 57.0%
# Validation accuracy: 53.7%
# Minibatch loss at step 6: 25.493111
# Minibatch accuracy: 91.4%
# Validation accuracy: 61.3%
# Minibatch loss at step 8: 89.439690
# Minibatch accuracy: 90.6%
# Validation accuracy: 62.2%
# Minibatch loss at step 10: 11.485412
# Minibatch accuracy: 96.9%
# Validation accuracy: 65.8%
# Minibatch loss at step 12: 3.449275
# Minibatch accuracy: 96.9%
# Validation accuracy: 65.0%
# Minibatch loss at step 14: 18.188704
# Minibatch accuracy: 98.4%
# Validation accuracy: 66.1%
# Minibatch loss at step 16: 1.388253
# Minibatch accuracy: 97.7%
# Validation accuracy: 65.0%
# Minibatch loss at step 18: 6.691193
# Minibatch accuracy: 96.9%
# Validation accuracy: 67.2%
# Minibatch loss at step 20: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.9%
# Minibatch loss at step 22: 3.946041
# Minibatch accuracy: 97.7%
# Validation accuracy: 66.8%
# Minibatch loss at step 24: 1.259270
# Minibatch accuracy: 99.2%
# Validation accuracy: 66.7%
# Minibatch loss at step 26: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 66.9%
# Minibatch loss at step 28: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.1%
# Minibatch loss at step 30: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 66.3%
# Minibatch loss at step 32: 1.996261
# Minibatch accuracy: 98.4%
# Validation accuracy: 66.0%
# Minibatch loss at step 34: 3.441518
# Minibatch accuracy: 98.4%
# Validation accuracy: 66.0%
# Minibatch loss at step 36: 0.462437
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.8%
# Minibatch loss at step 38: 0.092278
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.2%
# Minibatch loss at step 40: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.2%
# Minibatch loss at step 42: 0.373399
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.0%
# Minibatch loss at step 44: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 66.9%
# Minibatch loss at step 46: 0.381801
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.0%
# Minibatch loss at step 48: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.0%
# Minibatch loss at step 50: 0.204736
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.8%
# Minibatch loss at step 52: 0.454925
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.9%
# Minibatch loss at step 54: 1.956035
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.8%
# Minibatch loss at step 56: 2.410296
# Minibatch accuracy: 97.7%
# Validation accuracy: 68.0%
# Minibatch loss at step 58: 2.030764
# Minibatch accuracy: 99.2%
# Validation accuracy: 68.1%
# Minibatch loss at step 60: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 68.1%
# Minibatch loss at step 62: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 68.0%
# Minibatch loss at step 64: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 68.0%
# Minibatch loss at step 66: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 68.0%
# Minibatch loss at step 68: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 68.0%
# Minibatch loss at step 70: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 68.2%
# Minibatch loss at step 72: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.6%
# Minibatch loss at step 74: 5.622681
# Minibatch accuracy: 97.7%
# Validation accuracy: 67.0%
# Minibatch loss at step 76: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.5%
# Minibatch loss at step 78: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.6%
# Minibatch loss at step 80: 0.391562
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.7%
# Minibatch loss at step 82: 0.787713
# Minibatch accuracy: 98.4%
# Validation accuracy: 67.0%
# Minibatch loss at step 84: 0.422883
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.8%
# Minibatch loss at step 86: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.8%
# Minibatch loss at step 88: 3.600442
# Minibatch accuracy: 97.7%
# Validation accuracy: 66.4%
# Minibatch loss at step 90: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 66.4%
# Minibatch loss at step 92: 1.912472
# Minibatch accuracy: 99.2%
# Validation accuracy: 66.8%
# Minibatch loss at step 94: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.1%
# Minibatch loss at step 96: 0.552212
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.5%
# Minibatch loss at step 98: 0.029196
# Minibatch accuracy: 99.2%
# Validation accuracy: 67.5%
# Minibatch loss at step 100: 0.000000
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.5%
# Test accuracy: 73.9%

# %% [markdown]
# ---
# Problem 4
# ---------
#
# Try to get the best performance you can using a multi-layer model! The best reported test accuracy using a deep network is [97.1%](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html?showComment=1391023266211#c8758720086795711595).
#
# One avenue you can explore is to add multiple layers.
#
# Another one is to use learning rate decay:
#
#     global_step = tf.Variable(0)  # count the number of steps taken.
#     learning_rate = tf.train.exponential_decay(0.5, global_step, ...)
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
#
#  ---

# %%
batch_size = 128
num_hidden_nodes1 = 1024
num_hidden_nodes2 = 100
beta_regul = 1e-3

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0)

  # Variables.
  weights1 = tf.Variable(
    tf.truncated_normal(
        [image_size * image_size, num_hidden_nodes1],
        stddev=np.sqrt(2.0 / (image_size * image_size)))
    )
  biases1 = tf.Variable(tf.zeros([num_hidden_nodes1]))
  weights2 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes1, num_hidden_nodes2], stddev=np.sqrt(2.0 / num_hidden_nodes1)))
  biases2 = tf.Variable(tf.zeros([num_hidden_nodes2]))
  weights3 = tf.Variable(
    tf.truncated_normal([num_hidden_nodes2, num_labels], stddev=np.sqrt(2.0 / num_hidden_nodes2)))
  biases3 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  lay1_train = tf.nn.relu(tf.matmul(tf_train_dataset, weights1) + biases1)
  lay2_train = tf.nn.relu(tf.matmul(lay1_train, weights2) + biases2)
  logits = tf.matmul(lay2_train, weights3) + biases3
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)) + \
      beta_regul * (tf.nn.l2_loss(weights1) + tf.nn.l2_loss(weights2) + tf.nn.l2_loss(weights3))
  
  # Optimizer.
  learning_rate = tf.train.exponential_decay(0.5, global_step, 1000, 0.65, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  lay1_valid = tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1)
  lay2_valid = tf.nn.relu(tf.matmul(lay1_valid, weights2) + biases2)
  valid_prediction = tf.nn.softmax(tf.matmul(lay2_valid, weights3) + biases3)
  lay1_test = tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1)
  lay2_test = tf.nn.relu(tf.matmul(lay1_test, weights2) + biases2)
  test_prediction = tf.nn.softmax(tf.matmul(lay2_test, weights3) + biases3)

# %%
num_steps = 9001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From C:\Users\alex\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 3.296240
# Minibatch accuracy: 6.2%
# Validation accuracy: 37.8%
# Minibatch loss at step 500: 0.952018
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.7%
# Minibatch loss at step 1000: 0.873129
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 1500: 0.577239
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 2000: 0.503482
# Minibatch accuracy: 94.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 2500: 0.531658
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.5%
# Minibatch loss at step 3000: 0.553280
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 3500: 0.577892
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 4000: 0.442069
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 4500: 0.439357
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 5000: 0.507806
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 5500: 0.482032
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.6%
# Minibatch loss at step 6000: 0.576359
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.5%
# Minibatch loss at step 6500: 0.389273
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 7000: 0.521133
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.8%
# Minibatch loss at step 7500: 0.469016
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 8000: 0.589308
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 8500: 0.421735
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 9000: 0.479456
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.1%
# Test accuracy: 95.8%
