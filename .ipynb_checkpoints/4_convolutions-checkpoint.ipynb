# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.227358
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.1%
# Minibatch loss at step 50: 1.627879
# Minibatch accuracy: 37.5%
# Validation accuracy: 43.7%
# Minibatch loss at step 100: 1.008818
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.4%
# Minibatch loss at step 150: 0.292338
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.0%
# Minibatch loss at step 200: 0.978851
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.4%
# Minibatch loss at step 250: 1.009647
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 300: 0.342739
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 350: 0.476485
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 400: 0.270333
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 450: 0.710946
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 500: 0.564621
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 550: 1.071736
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 600: 0.344345
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 650: 0.968281
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 700: 0.867755
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 750: 0.091239
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.3%
# Minibatch loss at step 800: 0.548111
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 850: 1.101377
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 900: 0.599530
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 950: 0.562476
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 1000: 0.308571
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Test accuracy: 89.8%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    pool1 = tf.nn.max_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv2 = tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME')
    bias2 = tf.nn.relu(conv2 + layer2_biases)
    pool2 = tf.nn.max_pool(bias2, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool2.get_shape().as_list()
    reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From C:\Users\alex\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 3.362659
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.334721
# Minibatch accuracy: 0.0%
# Validation accuracy: 17.7%
# Minibatch loss at step 100: 1.798294
# Minibatch accuracy: 37.5%
# Validation accuracy: 26.9%
# Minibatch loss at step 150: 1.059247
# Minibatch accuracy: 50.0%
# Validation accuracy: 62.2%
# Minibatch loss at step 200: 1.181168
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.8%
# Minibatch loss at step 250: 1.471444
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.0%
# Minibatch loss at step 300: 0.390040
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 350: 0.605363
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.3%
# Minibatch loss at step 400: 0.234226
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 450: 0.747932
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.4%
# Minibatch loss at step 500: 0.628288
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 0.890806
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 600: 0.380910
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 650: 1.133443
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 700: 0.738194
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 750: 0.027967
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 800: 0.443661
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 850: 0.760218
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 900: 0.687190
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 950: 0.515933
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 1000: 0.516945
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Test accuracy: 89.9%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
  layer3_weights = tf.Variable(tf.truncated_normal(
      [size3 * size3 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    # C1 input 28 x 28
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    # S2 input 24 x 24
    pool2 = tf.nn.avg_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    # C3 input 12 x 12
    conv3 = tf.nn.conv2d(pool2, layer2_weights, [1, 1, 1, 1], padding='VALID')
    bias3 = tf.nn.relu(conv3 + layer2_biases)
    # S4 input 8 x 8
    pool4 = tf.nn.avg_pool(bias3, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    # F6 input 4 x 4
    shape = pool4.get_shape().as_list()
    reshape = tf.reshape(pool4, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels =tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 20001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From C:\Users\alex\Anaconda3\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 3.233507
# Minibatch accuracy: 18.8%
# Validation accuracy: 12.4%
# Minibatch loss at step 50: 1.693195
# Minibatch accuracy: 31.2%
# Validation accuracy: 45.0%
# Minibatch loss at step 100: 1.182336
# Minibatch accuracy: 62.5%
# Validation accuracy: 63.5%
# Minibatch loss at step 150: 0.891625
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.2%
# Minibatch loss at step 200: 1.026735
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.3%
# Minibatch loss at step 250: 1.065771
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 300: 0.475475
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.7%
# Minibatch loss at step 350: 0.690365
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.8%
# Minibatch loss at step 400: 0.360851
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 450: 0.873600
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 500: 0.819687
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.5%
# Minibatch loss at step 550: 0.830135
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 600: 0.427378
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 650: 0.755613
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 700: 1.009591
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 750: 0.061521
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 800: 0.580404
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 850: 1.182869
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 900: 0.796498
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 950: 0.640735
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 1000: 0.523674
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.6%
# Minibatch loss at step 1050: 0.609055
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 1100: 0.623265
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 1150: 0.477745
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 1200: 1.082259
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 1250: 0.616308
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 1300: 0.272635
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 1350: 1.068136
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 1400: 0.406927
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 1450: 0.357671
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 1500: 0.525808
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 1550: 0.769438
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 1600: 0.958233
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 1650: 0.447211
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 1700: 0.669720
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 1750: 0.463558
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 1800: 0.709215
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 1850: 0.831345
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 1900: 0.355957
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 1950: 0.639690
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 2000: 0.091134
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 2050: 0.675747
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 2100: 0.122231
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 2150: 0.612891
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 2200: 0.428007
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 2250: 0.631155
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 2300: 0.815120
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 2350: 0.360482
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 2400: 0.447144
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 2450: 0.599195
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 2500: 0.759990
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 2550: 0.506590
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 2600: 0.167441
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 2650: 0.490383
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 2700: 0.376317
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 2750: 1.482119
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 2800: 0.655647
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 2850: 0.105777
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 2900: 0.403403
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 2950: 0.411347
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 3000: 0.711419
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 3050: 0.449450
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 3100: 0.426883
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 3150: 0.642125
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 3200: 0.395583
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 3250: 0.396297
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 3300: 0.209235
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 3350: 0.405673
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 3400: 0.647405
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 3450: 0.495543
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 3500: 0.399564
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 3550: 0.152659
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 3600: 0.214618
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 3650: 0.877429
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 3700: 1.256611
# Minibatch accuracy: 62.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 3750: 0.930269
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 3800: 0.009006
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.3%
# Minibatch loss at step 3850: 0.585757
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 3900: 0.602934
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.5%
# Minibatch loss at step 3950: 0.027302
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 4000: 0.390878
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4050: 0.979673
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 4100: 0.407821
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 4150: 1.021281
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 4200: 0.360331
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 4250: 0.561216
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 4300: 0.720924
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 4350: 0.255287
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 4400: 1.198627
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 4450: 0.460727
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4500: 0.668849
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4550: 0.320141
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4600: 0.530913
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 4650: 0.706931
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 4700: 0.507356
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 4750: 0.963689
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 4800: 0.469551
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 4850: 0.330680
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 4900: 0.196334
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 4950: 0.234070
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 5000: 1.144554
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 5050: 0.288763
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 5100: 0.344601
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 5150: 0.468441
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 5200: 0.218356
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 5250: 0.116783
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 5300: 0.226135
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 5350: 0.266651
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 5400: 0.360457
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 5450: 0.309017
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 5500: 0.505057
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 5550: 0.402271
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 5600: 0.349828
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 5650: 0.432567
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 5700: 0.453672
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 5750: 0.508832
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 5800: 0.139533
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 5850: 0.650334
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 5900: 0.841258
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 5950: 0.349974
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 6000: 0.161697
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 6050: 0.364185
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 6100: 0.857021
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 6150: 0.196806
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 6200: 1.201408
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 6250: 0.902293
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 6300: 0.629106
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 6350: 0.179366
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 6400: 0.064733
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 6450: 0.315481
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 6500: 0.728052
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 6550: 0.235945
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 6600: 0.388605
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 6650: 1.471219
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 6700: 0.255674
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 6750: 0.311278
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 6800: 0.692901
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 6850: 0.613022
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 6900: 0.423212
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 6950: 0.158088
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 7000: 0.805355
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 7050: 0.840728
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 7100: 0.481747
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 7150: 0.243554
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 7200: 0.485301
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 7250: 0.345303
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 7300: 0.697497
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 7350: 0.189935
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 7400: 0.014853
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 7450: 0.318715
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 7500: 0.289946
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 7550: 0.395078
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 7600: 0.593620
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 7650: 0.182883
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 7700: 0.121017
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 7750: 0.387060
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 7800: 0.361466
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 7850: 0.476850
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 7900: 0.133724
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 7950: 0.762496
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 8000: 0.480716
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 8050: 0.322772
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 8100: 0.382071
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 8150: 0.735632
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.4%
# Minibatch loss at step 8200: 0.509098
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 8250: 0.289610
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 8300: 0.435003
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 8350: 0.551205
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 8400: 0.364978
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 8450: 0.236417
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 8500: 0.468002
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 8550: 0.387760
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 8600: 0.298135
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 8650: 0.540540
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 8700: 0.270386
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 8750: 0.108618
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 8800: 0.266019
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 8850: 0.015962
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 8900: 0.529234
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 8950: 0.386060
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 9000: 0.421294
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 9050: 0.378649
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 9100: 0.327738
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 9150: 0.858012
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 9200: 0.184386
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 9250: 0.915145
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 9300: 0.888789
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 9350: 0.287128
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 9400: 0.305025
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 9450: 0.433490
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 9500: 0.145039
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 9550: 0.264684
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 9600: 0.279309
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 9650: 0.457038
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 9700: 0.284969
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 9750: 0.127607
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 9800: 0.549488
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 9850: 0.273524
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 9900: 0.762470
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 9950: 0.302334
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 10000: 0.131585
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 10050: 0.027305
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 10100: 0.416038
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 10150: 0.674717
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 10200: 0.135322
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 10250: 0.521169
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 10300: 0.074727
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 10350: 0.653465
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 10400: 0.449529
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 10450: 0.260618
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 10500: 0.336792
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 10550: 0.893671
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 10600: 0.674571
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 10650: 0.415296
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 10700: 0.047206
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 10750: 0.253972
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 10800: 0.456598
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 10850: 0.866581
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 10900: 0.348188
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 10950: 0.534933
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 11000: 0.108656
# Minibatch accuracy: 100.0%
# Validation accuracy: 87