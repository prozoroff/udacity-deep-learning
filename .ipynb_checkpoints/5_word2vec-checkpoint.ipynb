# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-3446420b5935> in <module>()
#       7   for step in range(num_steps):
#       8     batch_data, batch_labels = generate_batch(
# ----> 9       batch_size, num_skips, skip_window)
#      10     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
#      11     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#
# TypeError: generate_batch() takes 2 positional arguments but 3 were given

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases,
                               train_labels, tf.reduce_sum(embeds, 1), num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.813237
# Nearest to world: microsoft, accented, schl, cccc, behaviours, beta, youssef, genomic,
# Nearest to the: kryptonian, cravings, folsom, scepticism, covens, affecting, consequence, unlikely,
# Nearest to i: dachshunds, denounced, eradicating, landform, rammed, cosgrave, internationalization, ideas,
# Nearest to may: alcal, sinkholes, vitamins, farthing, saban, elkins, buyer, rescue,
# Nearest to than: heed, psychosomatic, palatalized, raisins, oldcastle, sui, md, catapulted,
# Nearest to time: receptive, miraculously, fernand, enlistment, battlefield, nucleons, attic, acorns,
# Nearest to called: cadbury, mall, overrule, nozzle, suitor, judaean, nostratic, bastards,
# Nearest to only: happier, manganese, lads, articles, rz, troppo, somaliland, wallpapers,
# Nearest to other: indications, situational, turkmen, buffy, technocracy, unison, mediocre, density,
# Nearest to first: spiced, outweigh, getter, zed, culp, polar, chants, sgi,
# Nearest to over: edwards, godel, aluminum, immunotherapy, sarai, montagu, complicating, scruggs,
# Nearest to was: jainism, alnus, oxidise, homicidal, cabin, pty, gskola, aged,
# Nearest to b: disorders, efforts, desire, dien, magister, godf, poaching, verizon,
# Nearest to states: shadows, sends, vacations, ditka, psalter, mounting, ephemeral, pea,
# Nearest to by: bess, gte, app, query, kwh, barnard, discussions, albatross,
# Nearest to had: navigating, landmarks, marguerite, hobbies, aron, wizards, bri, defiant,
# Average loss at step 2000: 4.598035
# Average loss at step 4000: 3.885797
# Average loss at step 6000: 3.779665
# Average loss at step 8000: 3.676052
# Average loss at step 10000: 3.442586
# Nearest to world: tailpiece, popularized, franca, allure, cccc, tallinn, lymphoid, schl,
# Nearest to the: their, a, his, thrush, its, an, this, another,
# Nearest to i: we, g, ii, duodecimal, winograd, rightfully, olympians, santander,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to than: performer, dreamer, psychosomatic, emile, harbor, heed, aroma, assignments,
# Nearest to time: fanciful, properly, batsman, period, abacus, schoenberg, esters, anderson,
# Nearest to called: used, wholly, boulders, omnivores, valery, nozzle, overrule, vertebrates,
# Nearest to only: conferring, interpolated, pedagogical, spleen, gimme, wormhole, yields, coherence,
# Nearest to other: many, some, these, allegorical, different, conquests, all, various,
# Nearest to first: second, beings, official, seasoned, halifax, polar, capitulation, ozzy,
# Nearest to over: bowmen, purchased, councillors, baiting, moose, controlling, surreal, consult,
# Nearest to was: is, were, became, had, mourned, are, has, frication,
# Nearest to b: d, idolized, netbios, desiderius, underdeveloped, eclipsing, predicts, odds,
# Nearest to states: kingdom, twenty, nations, plated, baroness, lamp, ere, mojito,
# Nearest to by: and, realist, stagnation, bromley, toro, clay, albumin, fieldwork,
# Nearest to had: has, have, halmos, were, was, cursus, eisner, dependant,
# Average loss at step 12000: 3.565478
# Average loss at step 14000: 3.451684
# Average loss at step 16000: 3.403323
# Average loss at step 18000: 3.420265
# Average loss at step 20000: 3.372318
# Nearest to world: franca, contest, redistribution, bullseye, encryption, irssi, columba, inhabited,
# Nearest to the: thrush, their, its, a, his, ackroyd, an, folsom,
# Nearest to i: g, ii, we, you, fusing, santander, mail, authorize,
# Nearest to may: would, can, could, must, will, might, should, did,
# Nearest to than: but, dreamer, psychosomatic, melts, or, like, recently, rte,
# Nearest to time: end, least, yell, hdl, schoenberg, marginalism, gleichschaltung, point,
# Nearest to called: used, known, uv, derwent, where, considered, dehydrogenase, that,
# Nearest to only: ales, soa, praetors, nand, planned, let, hon, digitized,
# Nearest to other: various, different, all, merleau, these, many, several, conquests,
# Nearest to first: last, second, same, original, best, throughout, most, oldest,
# Nearest to over: through, nba, during, around, webmaster, from, within, payne,
# Nearest to was: is, became, were, had, has, are, does, mourned,
# Nearest to b: d, y, k, santo, millicent, disruptive, consuls, namespace,
# Nearest to states: kingdom, nations, mojito, chirality, cities, fanon, theaters, organelle,
# Nearest to by: when, provisional, forfeited, pawn, fieldwork, troubling, saviola, who,
# Nearest to had: has, have, was, having, were, halmos, became, rebel,
# Average loss at step 22000: 3.128593
# Average loss at step 24000: 3.313395
# Average loss at step 26000: 3.298654
# Average loss at step 28000: 3.263843
# Average loss at step 30000: 3.245732
# Nearest to world: bullseye, franca, neoliberalism, inhabited, phalanx, u, locates, tailpiece,
# Nearest to the: its, a, their, this, thrush, his, any, an,
# Nearest to i: g, ii, we, leyden, polemical, santander, agp, carbamazepine,
# Nearest to may: can, must, will, could, might, should, would, cannot,
# Nearest to than: but, henley, much, katrina, or, assignments, aroma, while,
# Nearest to time: least, times, point, beginning, period, contradicts, hdl, night,
# Nearest to called: used, known, considered, named, dehydrogenase, derwent, uv, anarcho,
# Nearest to only: still, no, phlogiston, nand, rewards, exemplify, hebrides, always,
# Nearest to other: various, different, these, local, psychiatric, those, spotting, sacking,
# Nearest to first: last, second, original, third, same, following, best, bootlegs,
# Nearest to over: around, within, through, about, across, before, inconvenient, under,
# Nearest to was: is, were, became, had, are, has, being, equaled,
# Nearest to b: d, c, odds, k, wiley, desu, noodle, onager,
# Nearest to states: kingdom, nations, orchestras, cities, lamp, vacations, purged, fanon,
# Nearest to by: when, ghosting, roshan, using, bromley, pony, repayment, from,
# Nearest to had: has, have, having, was, were, kokomo, aliasing, meiosis,
# Average loss at step 32000: 3.286208
# Average loss at step 34000: 3.215250
# Average loss at step 36000: 3.212640
# Average loss at step 38000: 3.129204
# Average loss at step 40000: 3.134318
# Nearest to world: franca, request, engagements, bulbs, ended, famines, hengest, elway,
# Nearest to the: its, his, a, thrush, their, an, any, hecuba,
# Nearest to i: g, ii, we, you, fusing, bawerk, smyrnaeans, polemical,
# Nearest to may: can, will, could, must, should, might, would, cannot,
# Nearest to than: or, but, dreamer, recently, and, graceful, efficient, pouches,
# Nearest to time: point, least, end, period, times, night, hdl, sheol,
# Nearest to called: known, used, named, considered, derwent, referred, see, employed,
# Nearest to only: mobile, still, no, exclusively, actually, centralize, stitch, seri,
# Nearest to other: various, reminds, different, these, individual, including, frankenheimer, others,
# Nearest to first: last, next, original, second, third, final, same, best,
# Nearest to over: around, under, across, through, dint, during, envy, watt,
# Nearest to was: is, were, became, are, being, had, remained, makes,
# Nearest to b: d, restriction, nymphs, collation, riso, chiron, ventral, democrats,
# Nearest to states: kingdom, nations, cheating, lamp, orchestras, scavullo, cities, kinshasa,
# Nearest to by: through, phylogeny, vec, without, unattractive, fieldwork, when, troubling,
# Nearest to had: has, have, having, was, were, would, includes, saw,
# Average loss at step 42000: 3.154942
# Average loss at step 44000: 3.148796
# Average loss at step 46000: 2.977166
# Average loss at step 48000: 3.078137
# Average loss at step 50000: 3.100222
# Nearest to world: request, ebay, europe, encryption, bullseye, elway, focussing, hengest,
# Nearest to the: its, their, a, any, thrush, his, an, bloodless,
# Nearest to i: ii, g, we, you, rapcore, authorize, santander, nasl,
# Nearest to may: can, might, should, will, would, must, could, cannot,
# Nearest to than: but, or, and, aroma, while, dreamer, enumerates, henley,
# Nearest to time: point, least, marginalism, beginning, period, year, georgi, age,
# Nearest to called: used, considered, known, referred, named, held, designed, derwent,
# Nearest to only: actually, no, previously, still, yitzchak, vila, islanders, it,
# Nearest to other: various, different, rather, watershed, many, certain, arnauld, several,
# Nearest to first: last, second, next, oldest, third, original, final, same,
# Nearest to over: through, across, around, despite, from, throughout, before, into,
# Nearest to was: is, were, became, had, are, becomes, remained, has,
# Nearest to b: d, c, namespace, xo, bikram, sigmund, gh, santo,
# Nearest to states: kingdom, nations, countries, languages, claims, rpp, cities, lamp,
# Nearest to by: through, under, forfeited, roshan, unranked, leafy, via, without,
# Nearest to had: has, have, having, was, saw, could, took, gave,
# Average loss at step 52000: 3.057840
# Average loss at step 54000: 2.973469
# Average loss at step 56000: 2.982436
# Average loss at step 58000: 2.998766
# Average loss at step 60000: 3.048813
# Nearest to world: bullseye, elway, u, hampering, europe, lightest, marketplace, chesterfield,
# Nearest to the: its, their, his, a, our, thrush, any, another,
# Nearest to i: g, ii, you, we, rightfully, nasl, fusing, sql,
# Nearest to may: might, can, could, must, will, cannot, should, would,
# Nearest to than: but, dreamer, or, fructose, katrina, adiabatic, donating, hand,
# Nearest to time: least, point, beginning, age, marginalism, batsman, period, times,
# Nearest to called: named, used, considered, introduced, known, derwent, included, referred,
# Nearest to only: presumes, no, mobile, fictitious, stitch, syllable, fully, leaded,
# Nearest to other: various, rather, arnauld, different, european, more, those, either,
# Nearest to first: last, second, next, original, throughout, third, fourth, highest,
# Nearest to over: through, depths, across, under, after, dasyprocta, adic, within,
# Nearest to was: is, were, became, are, had, been, becomes, has,
# Nearest to b: d, background, resonant, warwickshire, krahn, gard, captors, burger,
# Nearest to states: kingdom, nations, fanon, cheating, lamp, electrification, speculation, claims,
# Nearest to by: forfeited, via, through, without, ghosting, rightmost, realist, leafy,
# Nearest to had: has, have, having, was, voroshilov, agile, aliasing, includes,
# Average loss at step 62000: 2.987171
# Average loss at step 64000: 2.913032
# Average loss at step 66000: 3.032388
# Average loss at step 68000: 3.038700
# Average loss at step 70000: 2.886482
# Nearest to world: chesterfield, houser, paperback, falklands, nation, parisian, hampering, franca,
# Nearest to the: thrush, their, his, our, another, its, a, your,
# Nearest to i: ii, we, g, you, santander, skiego, mail, autistic,
# Nearest to may: might, can, should, could, must, cannot, would, will,
# Nearest to than: or, dreamer, donating, psychosomatic, but, aroma, subtropical, confrontational,
# Nearest to time: beginning, end, least, expense, look, night, period, point,
# Nearest to called: named, considered, known, referred, derwent, introduced, used, horne,
# Nearest to only: no, always, actually, andrzej, it, transfiguration, els, soa,
# Nearest to other: various, individual, rather, several, others, including, numerous, these,
# Nearest to first: last, next, second, same, earliest, oldest, original, third,
# Nearest to over: around, across, nearly, throughout, during, avignon, about, krush,
# Nearest to was: is, were, became, are, becomes, had, has, mourned,
# Nearest to b: d, resonant, rangle, kenneth, republik, captors, ladd, glutamate,
# Nearest to states: nations, kingdom, cities, claims, lamp, fanon, yetzirah, provinces,
# Nearest to by: roshan, ghosting, realist, leafy, without, thus, via, powering,
# Nearest to had: has, have, having, was, includes, could, were, requires,
# Average loss at step 72000: 2.967810
# Average loss at step 74000: 2.929749
# Average loss at step 76000: 2.948870
# Average loss at step 78000: 2.986867
# Average loss at step 80000: 2.857236
# Nearest to world: nation, espresso, falklands, country, bullseye, bulbs, paperback, jin,
# Nearest to the: its, a, his, any, thrush, their, our, an,
# Nearest to i: g, ii, mail, we, santander, bawerk, carbamazepine, wikibooks,
# Nearest to may: can, might, will, should, could, must, would, cannot,
# Nearest to than: or, psychosomatic, but, donating, dreamer, metrication, recently, melts,
# Nearest to time: least, end, times, night, period, expense, year, look,
# Nearest to called: named, used, allowed, termed, considered, introduced, known, referred,
# Nearest to only: always, actually, no, iia, nehemiah, heijenoort, anac, willful,
# Nearest to other: various, others, rather, many, both, tms, arnauld, most,
# Nearest to first: last, next, second, third, original, earliest, oldest, fourth,
# Nearest to over: around, across, during, throughout, within, nearly, off, avignon,
# Nearest to was: is, were, became, had, are, thurman, becomes, remains,
# Nearest to b: d, resonant, rangle, janssen, mpc, ladd, krahn, een,
# Nearest to states: nations, kingdom, claims, yetzirah, bonham, speculation, lamp, fanon,
# Nearest to by: through, without, ghosting, when, unattractive, realist, via, troubling,
# Nearest to had: has, have, having, holds, could, was, gave, includes,
# Average loss at step 82000: 2.925609
# Average loss at step 84000: 2.907774
# Average loss at step 86000: 2.735401
# Average loss at step 88000: 2.492390
# Average loss at step 90000: 2.741430
# Nearest to world: espresso, nation, hampering, gardeners, shellfish, jin, falklands, houser,
# Nearest to the: thrush, a, any, his, its, this, hecuba, another,
# Nearest to i: ii, we, g, you, mail, deems, rightfully, prussia,
# Nearest to may: might, can, should, could, must, would, will, cannot,
# Nearest to than: or, but, dreamer, psychosomatic, howling, melts, rte, donating,
# Nearest to time: point, period, night, times, era, look, expense, meeting,
# Nearest to called: named, considered, termed, used, created, described, formed, allowed,
# Nearest to only: always, first, willful, iia, actually, functionally, last, usually,
# Nearest to other: various, different, these, others, those, earlier, multiple, older,
# Nearest to first: last, next, second, third, oldest, same, final, earliest,
# Nearest to over: across, around, off, during, down, throughout, within, about,
# Nearest to was: is, became, were, exists, remains, are, remained, provides,
# Nearest to b: d, scalable, gard, interplay, enver, slander, stirred, priscus,
# Nearest to states: kingdom, nations, speculation, dictating, fanon, yetzirah, countries, state,
# Nearest to by: roshan, forfeited, keralite, with, unattractive, sobre, bromley, leafy,
# Nearest to had: has, have, having, was, saw, voroshilov, shropshire, gave,
# Average loss at step 92000: 2.888178
# Average loss at step 94000: 2.837540
# Average loss at step 96000: 2.941624
# Average loss at step 98000: 2.786079
# Average loss at step 100000: 2.847302
# Nearest to world: hospitalization, blaxploitation, country, theosophical, chesterfield, bullseye, espresso, galactica,
# Nearest to the: its, a, his, their, thrush, any, another, discord,
# Nearest to i: ii, you, we, they, feroze, carbamazepine, b, subgenus,
# Nearest to may: might, can, must, would, should, will, could, cannot,
# Nearest to than: or, but, psychosomatic, dreamer, sped, donating, oscillators, howling,
# Nearest to time: night, period, expense, point, times, least, moment, aimed,
# Nearest to called: named, termed, used, applied, considered, known, added, sorted,
# Nearest to only: always, actually, necessarily, until, first, every, stamped, synonymous,
# Nearest to other: various, older, rather, others, different, more, tms, stronger,
# Nearest to first: last, third, second, next, fourth, oldest, final, earliest,
# Nearest to over: across, around, through, within, throughout, beyond, under, during,
# Nearest to was: is, became, were, had, provides, makes, are, becomes,
# Nearest to b: d, pindar, i, enver, mail, woodwinds, booting, haley,
# Nearest to states: nations, kingdom, airlines, countries, speculation, state, rpp, vacations,
# Nearest to by: through, ghosting, troubling, forfeited, lattimore, fieldwork, via, when,
# Nearest to had: has, have, having, saw, was, could, holds, ve,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
